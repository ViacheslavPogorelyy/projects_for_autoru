# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
URL='https://baza.drom.ru/company/dokavto74'
req = requests.get(URL) # GET-запрос
soup = BeautifulSoup(req.text, 'lxml')

# %%
title = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('div', attrs = {'class':'bull-item-content__subject-container'}):
    title.append(row.text)

# %%
price = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('span', attrs = {'class':'price-per-quantity__price'}):
    price.append(row.text)

# %%
manufacture = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('div', attrs = {'class':'bull-item__annotation-row manufacturer'}):
    manufacture.append(row.text)

# %%
img = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('a', attrs = {'href':'/krasnodar/sell_spare_parts/oblicovka-rychaga-akpp-kia-rio-3-2017-846504y300wk-sedan-1.6-g4fc-123-l-s-g6979842327.html'}):
    img.append(row.text)

# %%
img
# Out:
# []

# %%
feed = pd.DataFrame()
new = pd.Series(manufacture)
feed['title'] = title
feed['price'] = price
feed['manufacture'] = new
#feed['manufacture'] = manufacture

# %%
feed['OEM']= feed['title'].str.split('[').str[1].str.split(']').str[0][:50]

# %%
feed['price'] = feed['price'].str.replace('₽', '')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
feed['category']= feed['title'].str.split(' ').str[0].str.split('(').str[0][:50]

# %%
import re

# %%
result = re.findall(r'\b([а-яА-ЯёЁ]+)', feed['title'][11])
print(result)
# Out:
# ['Трубка', 'топливная']

# %%
new = [] # Список, в котором хранятся названия запчастей
for i in range(len(feed['title'])):
    k = re.findall(r'\b[a-zA-Z]+.\b[a-zA-Z]+.\w+', feed['title'][i]) + re.findall(r'\d{4}–\d{4}', feed['title'][i])  
    new.append(k)

    
df12 = pd.DataFrame(data=new, columns=['lemmas', 'data'])

# %%
feed['compatibility'] = df12['lemmas'] + " " + df12['data']

# %%
display(feed)
# Out:
#                                                                                                   title  \
# 0   Фонарь задний (стоп сигнал) Toyota Mark II (X110) IX (2000–2002) [007B76817]
# 1   Обшивка стойки Toyota Mark II (X110) IX (2000–2002) [6241122370], правая
# 2   Крышка корпуса Toyota Mark II (X110) IX (2000–2002) [6403322120], задняя
# 3   Обшивка двери задней правой Ford Focus (III) III (2010–2015) [BM51A27406A]
# 4   Клапан вакуумный Chevrolet Aveo (T200) I (2002–2008) [96408135]
# 5   Трос открывания капота Toyota Mark II (X110) IX (2000–2002) [5363022240]
# 6   Педаль газа Toyota Mark II (X110) IX (2000–2002) [7801022040]
# 7   Проводка (коса) Toyota Mark II (X110) IX (2000–2002) [8217122750], правая передняя
# 8   Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261122280]
# 9   Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261222060]
# 10  Трубка кондиционера Toyota Mark II (X110) IX (2000–2002) [887123A890]
# 11  Трубка топливная Ford Focus (III) III (2010–2015) [AV619J280AD]
# 12  Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [6749122140], правая передняя
# 13  Воздуховод отопителя Toyota Mark II (X110) IX (2000–2002) [5596122100], правый передний
# 14  Защита топливного бака Toyota Mark II (X110) IX (2000–2002) [7729130070]
# 15  Крышка салонного фильтра Toyota Mark II (X110) IX (2000–2002) [5545922060]
# 16  Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [8856022010]
# 17  Подстаканник Chevrolet Epica I (2006–2009) [96439116]
# 18  Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7432022790A0], левый передний
# 19  Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7431022590], правый передний
# 20  Втулка подушки радиатора Toyota Mark II (X110) IX (2000–2002) [9048040021]
# 21  Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [5548022150A1]
# 22  Накладка консоли Toyota Mark II (X110) IX (2000–2002) [5540422190]
# 23  Заглушка Toyota Mark II (X110) IX (2000–2002)
# 24  Кронштейн радиатора Toyota Mark II (X110) IX (2000–2002) [1650546110]
# 25  Плафон салонный Toyota Mark II (X110) IX (2000–2002)
# 26  Трос стояночного тормоза Ford Focus (III) III (2010–2015) [AV612A603BJ]
# 27  Брызговик передний правый Ford Focus (III) III (2010–2015) [BM5JX16A262B]
# 28  Ковриков салона Chevrolet Epica I (2006–2009) К-кт [TM12062РЕ]
# 29  Механизм подрулевой для SRS (ленточный) Ford Focus (III) III (2010–2015) [AND761002C]
# 30  Корпус термостата Kia Rio (JB) II (2005–2009) [2560026100]
# 31  Крышка подушки безопасности (в рулевое колесо) Ford Focus (III) III (2010–2015) [AM51R02B85CDW]
# 32  Проводка (коса) Ford Focus (III) III (2010–2015) [34094701]
# 33  Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147AA]
# 34  Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147CA]
# 35  Шумоизоляция капота Ford Focus (III) III (2010–2015) [SD073JCIC344IP0141A02]
# 36  Поводок стеклоочистителя передний правый Ford Focus (III) III (2010–2015) [BM5117526BB]
# 37  Замок зажигания Ford Focus (III) III (2010–2015) [3M513F880AE]
# 38  Трос лючка бензобака Toyota Mark II (X110) IX (2000–2002) [77035-22230]
# 39  Ручка открывания багажника Toyota Mark II (X110) IX (2000–2002) [6460653010]
# 40  Обшивка крышки багажника Chevrolet Epica I (2006–2009) [96993921], задняя
# 41  Крышка багажника Chevrolet Epica I (2006–2009) [96636633], задняя
# 42  Фонарь подсветки номера Chevrolet Epica I (2006–2009) [LS077202], задний
# 43  Проводка (коса) Chevrolet Epica I (2006–2009) [96647116], задняя
# 44  Накладка крышки багажника Chevrolet Epica I (2006–2009) [96636421], задняя
# 45  Дверь передняя правая Ford Focus (III) III (2010–2015) [BM51A20220AL]
# 46  Дверь задняя правая Chevrolet Epica I (2006–2009) [96635658]
# 47  Дверь задняя правая Ford Focus (III) III (2010–2015) [2172763]
# 48  Дефлектор воздушный Toyota Mark II (X110) IX (2000–2002) [2556412160], правый передний
# 49  Кожух Toyota Mark II (X110) IX (2000–2002) [7322322010], задний
#
#      price     manufacture                    OEM      category  \
# 0   1 500   Toyota          007B76817              Фонарь
# 1   300     Toyota          6241122370             Обшивка
# 2   300     Toyota          6403322120             Крышка
# 3   1 000   Ford            BM51A27406A            Обшивка
# 4   500     General Motors  96408135               Клапан
# 5   800     Toyota          5363022240             Трос
# 6   500     Toyota          7801022040             Педаль
# 7   300     Toyota          8217122750             Проводка
# 8   700     Toyota          5261122280             Наполнитель
# 9   700     Toyota          5261222060             Наполнитель
# 10  500     Toyota          887123A890             Трубка
# 11  1 000   Ford            AV619J280AD            Трубка
# 12  500     Toyota          6749122140             Накладка
# 13  200     Toyota          5596122100             Воздуховод
# 14  400     Toyota          7729130070             Защита
# 15  500     Toyota          5545922060             Крышка
# 16  300     Toyota          8856022010             Накладка
# 17  300     General Motors  96439116               Подстаканник
# 18  700     Toyota          7432022790A0           Козырек
# 19  700     Toyota          7431022590             Козырек
# 20  100     Toyota          9048040021             Втулка
# 21  500     Toyota          5548022150A1           Накладка
# 22  400     Toyota          5540422190             Накладка
# 23  100     Toyota          NaN                    Заглушка
# 24  300     Toyota          1650546110             Кронштейн
# 25  300     Toyota          NaN                    Плафон
# 26  1 500   Ford            AV612A603BJ            Трос
# 27  500     Ford            BM5JX16A262B           Брызговик
# 28  1 000   General Motors  TM12062РЕ              Ковриков
# 29  1 500   Ford            AND761002C             Механизм
# 30  700     Hyundai/Kia     2560026100             Корпус
# 31  400     Ford            AM51R02B85CDW          Крышка
# 32  500     Ford            34094701               Проводка
# 33  500     Ford            AM5T14K147AA           Кнопка
# 34  400     Ford            AM5T14K147CA           Кнопка
# 35  400     Ford            SD073JCIC344IP0141A02  Шумоизоляция
# 36  700     Ford            BM5117526BB            Поводок
# 37  2 000   Ford            3M513F880AE            Замок
# 38  600     Toyota          77035-22230            Трос
# 39  500     Toyota          6460653010             Ручка
# 40  800     General Motors  96993921               Обшивка
# 41  9 000   General Motors  96636633               Крышка
# 42  350     General Motors  LS077202               Фонарь
# 43  350     General Motors  96647116               Проводка
# 44  1 000   General Motors  96636421               Накладка
# 45  18 000  Ford            BM51A20220AL           Дверь
# 46  9 000   General Motors  96635658               Дверь
# 47  17 000  Ford            2172763                Дверь
# 48  500     Toyota          2556412160             Дефлектор
# 49  300     Toyota          7322322010             Кожух
#
#                   compatibility
# 0   Toyota Mark II 2000–2002
# 1   Toyota Mark II 2000–2002
# 2   Toyota Mark II 2000–2002
# 3   Ford Focus 2010–2015
# 4   Chevrolet Aveo 2002–2008
# 5   Toyota Mark II 2000–2002
# 6   Toyota Mark II 2000–2002
# 7   Toyota Mark II 2000–2002
# 8   Toyota Mark II 2000–2002
# 9   Toyota Mark II 2000–2002
# 10  Toyota Mark II 2000–2002
# 11  Ford Focus 2010–2015
# 12  Toyota Mark II 2000–2002
# 13  Toyota Mark II 2000–2002
# 14  Toyota Mark II 2000–2002
# 15  Toyota Mark II 2000–2002
# 16  Toyota Mark II 2000–2002
# 17  Chevrolet Epica I 2006–2009
# 18  Toyota Mark II 2000–2002
# 19  Toyota Mark II 2000–2002
# 20  Toyota Mark II 2000–2002
# 21  Toyota Mark II 2000–2002
# 22  Toyota Mark II 2000–2002
# 23  Toyota Mark II 2000–2002
# 24  Toyota Mark II 2000–2002
# 25  Toyota Mark II 2000–2002
# 26  Ford Focus 2010–2015
# 27  Ford Focus 2010–2015
# 28  Chevrolet Epica I 2006–2009
# 29  Ford Focus 2010–2015
# 30  Kia Rio 2005–2009
# 31  Ford Focus 2010–2015
# 32  Ford Focus 2010–2015
# 33  Ford Focus 2010–2015
# 34  Ford Focus 2010–2015
# 35  Ford Focus 2010–2015
# 36  Ford Focus 2010–2015
# 37  Ford Focus 2010–2015
# 38  Toyota Mark II 2000–2002
# 39  Toyota Mark II 2000–2002
# 40  Chevrolet Epica I 2006–2009
# 41  Chevrolet Epica I 2006–2009
# 42  Chevrolet Epica I 2006–2009
# 43  Chevrolet Epica I 2006–2009
# 44  Chevrolet Epica I 2006–2009
# 45  Ford Focus 2010–2015
# 46  Chevrolet Epica I 2006–2009
# 47  Ford Focus 2010–2015
# 48  Toyota Mark II 2000–2002
# 49  Toyota Mark II 2000–2002

# %%
feed.to_excel("feed.xlsx")

# %%
result = re.search(r'\b[a-zA-Z]+', feed['title'][1] )
print(result)
# Out:
# <re.Match object; span=(15, 21), match='Toyota'>

# %%
result = re.split(r'\A[а-яА-ЯёЁ]+', feed['title'][33], maxsplit=0)
print(result)
# Out:
# ['', ' многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147AA]']

# %%
k = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('img'):
    k.append(row)

# %%
k
# Out:
# [<img alt="Док авто 74" src="https://static.baza.drom.ru/farpost_company/1510221531981_thumbnail120"/>,
#  <img class="company-profile-details__image" src="https://static.baza.drom.ru/farpost_company/1510221531981_thumbnail120"/>,
#  <img class="company-profile-details__image" src="https://static.baza.drom.ru/farpost_company/1510221531981_thumbnail120"/>,
#  <img alt="Фонарь задний (стоп сигнал) Toyota Mark II (X110) IX (2000–2002) [007B76817]" src="https://static.baza.drom.ru/v/1617287800147_block" title="Фонарь задний (стоп сигнал) Toyota Mark II (X110) IX (2000–2002) [007B76817] в Челябинске"/>,
#  <img alt="Обшивка стойки Toyota Mark II (X110) IX (2000–2002) [6241122370], правая" src="https://static.baza.drom.ru/v/1617287800142_block" title="Обшивка стойки Toyota Mark II (X110) IX (2000–2002) [6241122370], правая в Челябинске"/>,
#  <img alt="Крышка корпуса Toyota Mark II (X110) IX (2000–2002) [6403322120], задняя" src="https://static.baza.drom.ru/v/1617287800241_block" title="Крышка корпуса Toyota Mark II (X110) IX (2000–2002) [6403322120], задняя в Челябинске"/>,
#  <img alt="Обшивка двери задней правой Ford Focus (III) III (2010–2015) [BM51A27406A]" src="https://static.baza.drom.ru/v/1617287800289_block" title="Обшивка двери задней правой Ford Focus (III) III (2010–2015) [BM51A27406A] в Челябинске"/>,
#  <img alt="Клапан вакуумный Chevrolet Aveo (T200) I (2002–2008) [96408135]" src="https://static.baza.drom.ru/v/1617287800244_block" title="Клапан вакуумный Chevrolet Aveo (T200) I (2002–2008) [96408135] в Челябинске"/>,
#  <img alt="Трос открывания капота Toyota Mark II (X110) IX (2000–2002) [5363022240]" src="https://static.baza.drom.ru/v/1617287800290_block" title="Трос открывания капота Toyota Mark II (X110) IX (2000–2002) [5363022240] в Челябинске"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800310_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Педаль газа Toyota Mark II (X110) IX (2000–2002) [7801022040] в Челябинске"/>,
#  <img alt="Педаль газа Toyota Mark II (X110) IX (2000–2002) [7801022040]" src="https://static.baza.drom.ru/v/1617287800310_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800433_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Проводка (коса) Toyota Mark II (X110) IX (2000–2002) [8217122750], правая передняя в Челябинске"/>,
#  <img alt="Проводка (коса) Toyota Mark II (X110) IX (2000–2002) [8217122750], правая передняя" src="https://static.baza.drom.ru/v/1617287800433_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800371_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261122280] в Челябинске"/>,
#  <img alt="Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261122280]" src="https://static.baza.drom.ru/v/1617287800371_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800484_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261222060] в Челябинске"/>,
#  <img alt="Наполнитель переднего бампера Toyota Mark II (X110) IX (2000–2002) [5261222060]" src="https://static.baza.drom.ru/v/1617287800484_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800543_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Трубка кондиционера Toyota Mark II (X110) IX (2000–2002) [887123A890] в Челябинске"/>,
#  <img alt="Трубка кондиционера Toyota Mark II (X110) IX (2000–2002) [887123A890]" src="https://static.baza.drom.ru/v/1617287800543_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800503_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Трубка топливная Ford Focus (III) III (2010–2015) [AV619J280AD] в Челябинске"/>,
#  <img alt="Трубка топливная Ford Focus (III) III (2010–2015) [AV619J280AD]" src="https://static.baza.drom.ru/v/1617287800503_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800424_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [6749122140], правая передняя в Челябинске"/>,
#  <img alt="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [6749122140], правая передняя" src="https://static.baza.drom.ru/v/1617287800424_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800470_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Воздуховод отопителя Toyota Mark II (X110) IX (2000–2002) [5596122100], правый передний в Челябинске"/>,
#  <img alt="Воздуховод отопителя Toyota Mark II (X110) IX (2000–2002) [5596122100], правый передний" src="https://static.baza.drom.ru/v/1617287800470_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800559_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Защита топливного бака Toyota Mark II (X110) IX (2000–2002) [7729130070] в Челябинске"/>,
#  <img alt="Защита топливного бака Toyota Mark II (X110) IX (2000–2002) [7729130070]" src="https://static.baza.drom.ru/v/1617287800559_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1617287800729_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Крышка салонного фильтра Toyota Mark II (X110) IX (2000–2002) [5545922060] в Челябинске"/>,
#  <img alt="Крышка салонного фильтра Toyota Mark II (X110) IX (2000–2002) [5545922060]" src="https://static.baza.drom.ru/v/1617287800729_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652780_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [8856022010] в Челябинске"/>,
#  <img alt="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [8856022010]" src="https://static.baza.drom.ru/v/1616855652780_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652784_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Подстаканник Chevrolet Epica I (2006–2009) [96439116] в Челябинске"/>,
#  <img alt="Подстаканник Chevrolet Epica I (2006–2009) [96439116]" src="https://static.baza.drom.ru/v/1616855652784_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652808_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7432022790A0], левый передний в Челябинске"/>,
#  <img alt="Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7432022790A0], левый передний" src="https://static.baza.drom.ru/v/1616855652808_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652886_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7431022590], правый передний в Челябинске"/>,
#  <img alt="Козырек солнцезащитный (внутри) Toyota Mark II (X110) IX (2000–2002) [7431022590], правый передний" src="https://static.baza.drom.ru/v/1616855652886_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652880_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Втулка подушки радиатора Toyota Mark II (X110) IX (2000–2002) [9048040021] в Челябинске"/>,
#  <img alt="Втулка подушки радиатора Toyota Mark II (X110) IX (2000–2002) [9048040021]" src="https://static.baza.drom.ru/v/1616855652880_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652868_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [5548022150A1] в Челябинске"/>,
#  <img alt="Накладка декоративная Toyota Mark II (X110) IX (2000–2002) [5548022150A1]" src="https://static.baza.drom.ru/v/1616855652868_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652873_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Накладка консоли Toyota Mark II (X110) IX (2000–2002) [5540422190] в Челябинске"/>,
#  <img alt="Накладка консоли Toyota Mark II (X110) IX (2000–2002) [5540422190]" src="https://static.baza.drom.ru/v/1616855652873_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652951_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Заглушка Toyota Mark II (X110) IX (2000–2002) в Челябинске"/>,
#  <img alt="Заглушка Toyota Mark II (X110) IX (2000–2002)" src="https://static.baza.drom.ru/v/1616855652951_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652897_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Кронштейн радиатора Toyota Mark II (X110) IX (2000–2002) [1650546110] в Челябинске"/>,
#  <img alt="Кронштейн радиатора Toyota Mark II (X110) IX (2000–2002) [1650546110]" src="https://static.baza.drom.ru/v/1616855652897_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652898_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Плафон салонный Toyota Mark II (X110) IX (2000–2002) в Челябинске"/>,
#  <img alt="Плафон салонный Toyota Mark II (X110) IX (2000–2002)" src="https://static.baza.drom.ru/v/1616855652898_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652891_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Трос стояночного тормоза Ford Focus (III) III (2010–2015) [AV612A603BJ] в Челябинске"/>,
#  <img alt="Трос стояночного тормоза Ford Focus (III) III (2010–2015) [AV612A603BJ]" src="https://static.baza.drom.ru/v/1616855652891_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652926_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Брызговик передний правый Ford Focus (III) III (2010–2015) [BM5JX16A262B] в Челябинске"/>,
#  <img alt="Брызговик передний правый Ford Focus (III) III (2010–2015) [BM5JX16A262B]" src="https://static.baza.drom.ru/v/1616855652926_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652902_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Ковриков салона Chevrolet Epica I (2006–2009) К-кт [TM12062РЕ] в Челябинске"/>,
#  <img alt="Ковриков салона Chevrolet Epica I (2006–2009) К-кт [TM12062РЕ]" src="https://static.baza.drom.ru/v/1616855652902_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652905_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Механизм подрулевой для SRS (ленточный) Ford Focus (III) III (2010–2015) [AND761002C] в Челябинске"/>,
#  <img alt="Механизм подрулевой для SRS (ленточный) Ford Focus (III) III (2010–2015) [AND761002C]" src="https://static.baza.drom.ru/v/1616855652905_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652937_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Корпус термостата Kia Rio (JB) II (2005–2009) [2560026100] в Челябинске"/>,
#  <img alt="Корпус термостата Kia Rio (JB) II (2005–2009) [2560026100]" src="https://static.baza.drom.ru/v/1616855652937_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652954_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Крышка подушки безопасности (в рулевое колесо) Ford Focus (III) III (2010–2015) [AM51R02B85CDW] в Челябинске"/>,
#  <img alt="Крышка подушки безопасности (в рулевое колесо) Ford Focus (III) III (2010–2015) [AM51R02B85CDW]" src="https://static.baza.drom.ru/v/1616855652954_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652941_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Проводка (коса) Ford Focus (III) III (2010–2015) [34094701] в Челябинске"/>,
#  <img alt="Проводка (коса) Ford Focus (III) III (2010–2015) [34094701]" src="https://static.baza.drom.ru/v/1616855652941_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855652956_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147AA] в Челябинске"/>,
#  <img alt="Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147AA]" src="https://static.baza.drom.ru/v/1616855652956_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653007_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147CA] в Челябинске"/>,
#  <img alt="Кнопка многофункциональная Ford Focus (III) III (2010–2015) [AM5T14K147CA]" src="https://static.baza.drom.ru/v/1616855653007_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653051_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Шумоизоляция капота Ford Focus (III) III (2010–2015) [SD073JCIC344IP0141A02] в Челябинске"/>,
#  <img alt="Шумоизоляция капота Ford Focus (III) III (2010–2015) [SD073JCIC344IP0141A02]" src="https://static.baza.drom.ru/v/1616855653051_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653039_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Поводок стеклоочистителя передний правый Ford Focus (III) III (2010–2015) [BM5117526BB] в Челябинске"/>,
#  <img alt="Поводок стеклоочистителя передний правый Ford Focus (III) III (2010–2015) [BM5117526BB]" src="https://static.baza.drom.ru/v/1616855653039_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653061_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Замок зажигания Ford Focus (III) III (2010–2015) [3M513F880AE] в Челябинске"/>,
#  <img alt="Замок зажигания Ford Focus (III) III (2010–2015) [3M513F880AE]" src="https://static.baza.drom.ru/v/1616855653061_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653169_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Трос лючка бензобака Toyota Mark II (X110) IX (2000–2002) [77035-22230] в Челябинске"/>,
#  <img alt="Трос лючка бензобака Toyota Mark II (X110) IX (2000–2002) [77035-22230]" src="https://static.baza.drom.ru/v/1616855653169_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653042_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Ручка открывания багажника Toyota Mark II (X110) IX (2000–2002) [6460653010] в Челябинске"/>,
#  <img alt="Ручка открывания багажника Toyota Mark II (X110) IX (2000–2002) [6460653010]" src="https://static.baza.drom.ru/v/1616855653042_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653043_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Обшивка крышки багажника Chevrolet Epica I (2006–2009) [96993921], задняя в Челябинске"/>,
#  <img alt="Обшивка крышки багажника Chevrolet Epica I (2006–2009) [96993921], задняя" src="https://static.baza.drom.ru/v/1616855653043_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653054_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Крышка багажника Chevrolet Epica I (2006–2009) [96636633], задняя в Челябинске"/>,
#  <img alt="Крышка багажника Chevrolet Epica I (2006–2009) [96636633], задняя" src="https://static.baza.drom.ru/v/1616855653054_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653066_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Фонарь подсветки номера Chevrolet Epica I (2006–2009) [LS077202], задний в Челябинске"/>,
#  <img alt="Фонарь подсветки номера Chevrolet Epica I (2006–2009) [LS077202], задний" src="https://static.baza.drom.ru/v/1616855653066_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653110_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Проводка (коса) Chevrolet Epica I (2006–2009) [96647116], задняя в Челябинске"/>,
#  <img alt="Проводка (коса) Chevrolet Epica I (2006–2009) [96647116], задняя" src="https://static.baza.drom.ru/v/1616855653110_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653065_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Накладка крышки багажника Chevrolet Epica I (2006–2009) [96636421], задняя в Челябинске"/>,
#  <img alt="Накладка крышки багажника Chevrolet Epica I (2006–2009) [96636421], задняя" src="https://static.baza.drom.ru/v/1616855653065_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653148_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Дверь передняя правая Ford Focus (III) III (2010–2015) [BM51A20220AL] в Челябинске"/>,
#  <img alt="Дверь передняя правая Ford Focus (III) III (2010–2015) [BM51A20220AL]" src="https://static.baza.drom.ru/v/1616855653148_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653283_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Дверь задняя правая Chevrolet Epica I (2006–2009) [96635658] в Челябинске"/>,
#  <img alt="Дверь задняя правая Chevrolet Epica I (2006–2009) [96635658]" src="https://static.baza.drom.ru/v/1616855653283_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616855653212_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Дверь задняя правая Ford Focus (III) III (2010–2015) [2172763] в Челябинске"/>,
#  <img alt="Дверь задняя правая Ford Focus (III) III (2010–2015) [2172763]" src="https://static.baza.drom.ru/v/1616855653212_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616942031832_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Дефлектор воздушный Toyota Mark II (X110) IX (2000–2002) [2556412160], правый передний в Челябинске"/>,
#  <img alt="Дефлектор воздушный Toyota Mark II (X110) IX (2000–2002) [2556412160], правый передний" src="https://static.baza.drom.ru/v/1616942031832_block"/>,
#  <img align="middle" class="lazyLoad bull-image-echo" data-echo="https://static.baza.drom.ru/v/1616942031877_block" src="https://static.baza.drom.ru/resources/img/viewdir/dotloader_45px.gif" title="Кожух Toyota Mark II (X110) IX (2000–2002) [7322322010], задний в Челябинске"/>,
#  <img alt="Кожух Toyota Mark II (X110) IX (2000–2002) [7322322010], задний" src="https://static.baza.drom.ru/v/1616942031877_block"/>]

# %%
result = re.findall(r'\d{4}–\d{4}', 'Фонарь задний (стоп сигнал) Toyota Mark II (X110) IX 2000–2002  [007B76817]')
print(result)
# Out:
# ['2000–2002']
