# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup 
import re
import numpy as np
import requests as r

# %%
URL='https://baza.drom.ru/company/dokavto74/'
req = requests.get(URL) # GET-запрос
soup = BeautifulSoup(req.text, 'lxml')

# %%
title = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('div', attrs = {'class':'bull-item-content__subject-container'}):
    title.append(row.text)

# %%
price = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('span', attrs = {'class':'price-per-quantity__price'}):
    price.append(row.text)

# %%
manufacture = [] # Список, в котором хранятся названия запчастей
for row in soup.find_all('div', attrs = {'class':'bull-item__annotation-row manufacturer'}):
    manufacture.append(row.text)

# %%
feed = pd.DataFrame()

# %%
text = r.get('https://baza.drom.ru/company/dokavto74/').text
k = re.findall(r'(https://static.baza.drom.ru/v/+\d{13}\D\w{5})', text)
img = pd.DataFrame(data = k, columns = ['img'])
img = img.drop_duplicates(subset=['img']).reset_index()

# %%
feed['title'] = title
feed['price'] = price
feed['price'] = feed['price'].str.replace('₽', '')
feed['manufacture'] = pd.Series(manufacture)
feed['OEM']= feed['title'].str.split('[').str[1].str.split(']').str[0][:50]
feed['category']= feed['title'].str.split(' ').str[0].str.split('(').str[0][:50]
feed['image'] = img['img']

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-225-0891b765a168>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
feed['category']= feed['title'].str.split(' ').str[0].str.split('(').str[0][:50]

# %%
new = [] # Список, в котором хранятся названия запчастей
for i in range(len(feed['title'])):
    k = re.findall(r'\b[a-zA-Z]+.\b[a-zA-Z]+.\w+', feed['title'][i]) + re.findall(r'\d{4}–\d{4}', feed['title'][i])  
    new.append(k)

    
df12 = pd.DataFrame(data=new, columns=['lemmas', 'data'])

# %%
feed['compatibility'] = df12['lemmas'] + " " + df12['data']

# %%
feed
# Out:
#                                                                                     title  \
# 0   Маховик Ford Focus (III) III (2010–2015) [AV616375AB]
# 1   Блок управления двигателем Kia Rio (JB) II (2005–2009) [9030930616A6]
# 2   Блок ABS (насос) Ford Focus (III) III (2010–2015) [BV612M110AC]
# 3   Абсорбер (фильтр угольный) Ford Focus (III) III (2010–2015) [7M519E857CC]
# 4   Рейка топливная (рампа) Chevrolet Epica I (2006–2009) [280158097]
# 5   Форсунка инжекторная электрическая Chevrolet Epica I (2006–2009) [0280158097]
# 6   Крышка двигателя передняя Kia Rio (JB) II (2005–2009) [2240526030]
# 7   Кожух ремня ГРМ Kia Rio (JB) II (2005–2009) [2135026001]
# 8   Кожух ремня ГРМ Kia Rio (JB) II (2005–2009) [2136026002]
# 9   Сайлентблок заднего попер. рычага Hyundai Elantra (HD) IV (2006–2012) [551181D000]
# 10  Колодки тормозные задние дисковые к-кт Toyota Corolla (E150) X (2006–2010) [181514]
# 11  Наконечник рулевой Audi 80 (B1) I (1972–1976) [5100153SX], передний
# 12  Подшипник поворотного кулака Toyota Corolla (E110) VIII (1995–2000) [WB1231]
# 13  Подшипник выжимной Toyota RAV4 (CA20) II (2000–2003) [RCT337SA32]
# 14  Резистор отопителя Nissan Micra (K12) III (2002–2005) [665055]
# 15  Ролик-натяжитель Mitsubishi Pajero Mini II (1998–2008) [Abtmi1004]
# 16  Крестовина рулевого кардана Toyota Camry (XV30) VI (2001–2006) [AS1639]
# 17  Крышка расширительного бачка Citroen Berlingo (M49) I (1996–2002) [RC218]
# 18  Термостат Suzuki Aerio I рестайлинг (2003–2007) [TH35682G1]
# 19  Термостат Toyota Corolla (E100) VII (1991–2002) [2340012SX]
# 20  Пыльник нар/пер. ШРУСа (к-кт) Chevrolet Aveo (T250) I рестайлинг (2005–2011) [303901]
# 21  Стойка переднего стабилизатора Chevrolet Captiva I (2006–2011) [CLKD15R]
# 22  Пыльник ШРУСа наружного пер Toyota RAV4 (XA20) II (2000–2003) [02163], передний
# 23  Пыльник ШРУСа наружного пер Toyota Corolla Levin (E100) VI (1991–1993) [02144]
# 24  Прокладка EGR Ford Mondeo (4) IV (2007–2010) [1379873]
# 25  Прокладка турбокомпрессора (турбины) Ford Mondeo (4) IV (2007–2010) [1352882]
# 26  Сальник коленвала передний Renault Logan I (2004-2015) [813348910]
# 27  Фильтр масляный Opel Astra (F) I рестайлинг (1994–2000) [2329900]
# 28  Фильтр масляный Ford Mondeo (4) IV (2007–2010) [1343102]
# 29  Фильтр масляный Ford Transit (Mark 7) VII (2006-2015) [HU71151X]
# 30  Фильтр масляный Chevrolet Aveo (T200) I (2002–2008) [OC4053]
# 31  Фильтр масляный Volvo S60 (P24) I (2000–2004) [OE662]
# 32  Фильтр масляный Toyota Corolla Levin (E100) VI (1991–1993) [T1636]
# 33  Фильтр масляный Toyota Corolla (E20) II (1970–1978) [OG212HQ]
# 34  Фильтр масляный Volvo S40 (MS) II (2004–2007) [OE662]
# 35  Колодки барабанные к-кт Hyundai Elantra (HD) IV (2006–2012) [GS8489]
# 36  Пыльник рулевой рейки Kia Sorento (XM) II (2009–2012) [577402P000], передний
# 37  Тяга рулевая Nissan Tiida (C11) I (2004–2010) [MR4950]
# 38  Наконечник рулевой Hyundai Sonata (EF) IV (1998–2001) [SN2153]
# 39  Наконечник рулевой Hyundai Sonata (EF) IV (1998–2001) [SN2154]
# 40  Диск сцепления Toyota Avensis (T250) II (2002–2006) [1878634079]
# 41  Рычаг передний верхний Volkswagen Touareg (NF) II (2010–2014) [K195303]
# 42  Прокладка (двигатель) Daewoo Matiz (M150) I рестайлинг (2000–2015) [P93740913]
# 43  Прокладка (двигатель) Kia Spectra (LD) II (2004–2006) [K0AB410270]
# 44  Молдинг Kia Rio (QB) III (2011–2015) [FW3482]
# 45  Насос топливный электрический Kia Rio (JB) II (2005–2009) [311101G000], задний
# 46  Торпедо Kia Rio (JB) II (2005–2009) [847101G100XI], передний
# 47  Обшивка двери передней левой Kia Rio (JB) II (2005–2009) [823301GXXX]
# 48  Бак топливный Kia Rio (JB) II (2005–2009) [311501G200], задний
# 49  Панель задняя Kia Rio (JB) II (2005–2009)
#
#     price      manufacture           OEM          category  \
# 0   1 500  Ford             AV616375AB    Маховик
# 1   2 000  Hyundai/Kia      9030930616A6  Блок
# 2   2 000  Ford             BV612M110AC   Блок
# 3   1 000  Ford             7M519E857CC   Абсорбер
# 4   1 000  General Motors   280158097     Рейка
# 5   400    General Motors   0280158097    Форсунка
# 6   700    Hyundai/Kia      2240526030    Крышка
# 7   500    Hyundai/Kia      2135026001    Кожух
# 8   500    Hyundai/Kia      2136026002    Кожух
# 9   350    Hyundai/Kia      551181D000    Сайлентблок
# 10  1 200  Toyota           181514        Колодки
# 11  300    VAG              5100153SX     Наконечник
# 12  1 250  Toyota           WB1231        Подшипник
# 13  1 200  Toyota           RCT337SA32    Подшипник
# 14  1 400  Nissan           665055        Резистор
# 15  2 800  Toyota           Abtmi1004     Ролик-натяжитель
# 16  200    Citroen/Peugeot  AS1639        Крестовина
# 17  600    Suzuki           RC218         Крышка
# 18  600    Toyota           TH35682G1     Термостат
# 19  500    General Motors   2340012SX     Термостат
# 20  700    General Motors   303901        Пыльник
# 21  400    Toyota           CLKD15R       Стойка
# 22  500    Toyota           02163         Пыльник
# 23  500    Ford             02144         Пыльник
# 24  400    Ford             1379873       Прокладка
# 25  400    Logan            1352882       Прокладка
# 26  550    Ford             813348910     Сальник
# 27  200    Ford             2329900       Фильтр
# 28  750    General Motors   1343102       Фильтр
# 29  450    Volvo            HU71151X      Фильтр
# 30  200    Toyota           OC4053        Фильтр
# 31  200    Toyota           OE662         Фильтр
# 32  250    Volvo            T1636         Фильтр
# 33  200    Hyundai/Kia      OG212HQ       Фильтр
# 34  400    Hyundai/Kia      OE662         Фильтр
# 35  2 500  Nissan           GS8489        Колодки
# 36  550    Hyundai/Kia      577402P000    Пыльник
# 37  650    Hyundai/Kia      MR4950        Тяга
# 38  550    Toyota           SN2153        Наконечник
# 39  550    VAG              SN2154        Наконечник
# 40  5 000  Daewoo           1878634079    Диск
# 41  3 000  Ld               K195303       Рычаг
# 42  1 300  Hyundai/Kia      P93740913     Прокладка
# 43  1 000  Hyundai/Kia      K0AB410270    Прокладка
# 44  500    Hyundai/Kia      FW3482        Молдинг
# 45  2 500  Hyundai/Kia      311101G000    Насос
# 46  4 000  Hyundai/Kia      847101G100XI  Торпедо
# 47  800    Hyundai/Kia      823301GXXX    Обшивка
# 48  3 000  NaN              311501G200    Бак
# 49  6 000  NaN              NaN           Панель
#
#                                                 image  \
# 0   https://static.baza.drom.ru/v/1618584242113_block
# 1   https://static.baza.drom.ru/v/1618584242104_block
# 2   https://static.baza.drom.ru/v/1618584242151_block
# 3   https://static.baza.drom.ru/v/1618584242172_block
# 4   https://static.baza.drom.ru/v/1618584242188_block
# 5   https://static.baza.drom.ru/v/1618584242274_block
# 6   https://static.baza.drom.ru/v/1618584242526_block
# 7   https://static.baza.drom.ru/v/1618584242357_block
# 8   https://static.baza.drom.ru/v/1618584242315_block
# 9   https://static.baza.drom.ru/v/1617893117310_block
# 10  https://static.baza.drom.ru/v/1617893117225_block
# 11  https://static.baza.drom.ru/v/1617980119983_block
# 12  https://static.baza.drom.ru/v/1617980119925_block
# 13  https://static.baza.drom.ru/v/1617980119955_block
# 14  https://static.baza.drom.ru/v/1617980119946_block
# 15  https://static.baza.drom.ru/v/1617980119992_block
# 16  https://static.baza.drom.ru/v/1617980120002_block
# 17  https://static.baza.drom.ru/v/1617980120006_block
# 18  https://static.baza.drom.ru/v/1617980120057_block
# 19  https://static.baza.drom.ru/v/1617980120121_block
# 20  https://static.baza.drom.ru/v/1617980120082_block
# 21  https://static.baza.drom.ru/v/1617980120086_block
# 22  https://static.baza.drom.ru/v/1617980120187_block
# 23  https://static.baza.drom.ru/v/1617980120034_block
# 24  https://static.baza.drom.ru/v/1617980120075_block
# 25  https://static.baza.drom.ru/v/1617980120037_block
# 26  https://static.baza.drom.ru/v/1617980120154_block
# 27  https://static.baza.drom.ru/v/1617980120180_block
# 28  https://static.baza.drom.ru/v/1617980120209_block
# 29  https://static.baza.drom.ru/v/1617980120126_block
# 30  https://static.baza.drom.ru/v/1617980120170_block
# 31  https://static.baza.drom.ru/v/1617980120233_block
# 32  https://static.baza.drom.ru/v/1617980120149_block
# 33  https://static.baza.drom.ru/v/1617980120221_block
# 34  https://static.baza.drom.ru/v/1617980120207_block
# 35  https://static.baza.drom.ru/v/1617980120178_block
# 36  https://static.baza.drom.ru/v/1617980120140_block
# 37  https://static.baza.drom.ru/v/1617980120192_block
# 38  https://static.baza.drom.ru/v/1617980120228_block
# 39  https://static.baza.drom.ru/v/1617980120225_block
# 40  https://static.baza.drom.ru/v/1617980120240_block
# 41  https://static.baza.drom.ru/v/1617980120234_block
# 42  https://static.baza.drom.ru/v/1617980120341_block
# 43  https://static.baza.drom.ru/v/1618065862016_block
# 44  https://static.baza.drom.ru/v/1618065861974_block
# 45  https://static.baza.drom.ru/v/1618497763450_block
# 46  https://static.baza.drom.ru/v/1618497763820_block
# 47  https://static.baza.drom.ru/v/1618497764245_block
# 48  https://static.baza.drom.ru/v/1618497764368_block
# 49  https://static.baza.drom.ru/v/1618497764448_block
#
#                        compatibility
# 0   Ford Focus 2010–2015
# 1   Kia Rio 2005–2009
# 2   Ford Focus 2010–2015
# 3   Ford Focus 2010–2015
# 4   Chevrolet Epica I 2006–2009
# 5   Chevrolet Epica I 2006–2009
# 6   Kia Rio 2005–2009
# 7   Kia Rio 2005–2009
# 8   Kia Rio 2005–2009
# 9   Hyundai Elantra 2006–2012
# 10  Toyota Corolla 2006–2010
# 11  NaN
# 12  Toyota Corolla 1995–2000
# 13  Toyota RAV4 2000–2003
# 14  Nissan Micra 2002–2005
# 15  Mitsubishi Pajero Mini 1998–2008
# 16  Toyota Camry 2001–2006
# 17  Citroen Berlingo 1996–2002
# 18  Suzuki Aerio I 2003–2007
# 19  Toyota Corolla 1991–2002
# 20  Chevrolet Aveo 2005–2011
# 21  Chevrolet Captiva I 2006–2011
# 22  Toyota RAV4 2000–2003
# 23  Toyota Corolla Levin 1991–1993
# 24  EGR Ford Mondeo 2007–2010
# 25  Ford Mondeo 2007–2010
# 26  NaN
# 27  Opel Astra 1994–2000
# 28  Ford Mondeo 2007–2010
# 29  NaN
# 30  Chevrolet Aveo 2002–2008
# 31  Volvo S60 2000–2004
# 32  Toyota Corolla Levin 1991–1993
# 33  Toyota Corolla 1970–1978
# 34  Volvo S40 2004–2007
# 35  Hyundai Elantra 2006–2012
# 36  Kia Sorento 2009–2012
# 37  Nissan Tiida 2004–2010
# 38  Hyundai Sonata 1998–2001
# 39  Hyundai Sonata 1998–2001
# 40  Toyota Avensis 2002–2006
# 41  Volkswagen Touareg 2010–2014
# 42  Daewoo Matiz 2000–2015
# 43  Kia Spectra 2004–2006
# 44  Kia Rio 2011–2015
# 45  Kia Rio 2005–2009
# 46  Kia Rio 2005–2009
# 47  Kia Rio 2005–2009
# 48  Kia Rio 2005–2009
# 49  Kia Rio 2005–2009

# %%
feed.to_excel("feed.xlsx")
